# %% [markdown]
# <a href="https://colab.research.google.com/github/pranathi139/GenAI/blob/main/Week3_Web_Scraping_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 schedule

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import smtplib
import schedule
import time

# %%
def fetch_news():
    url = "https://news.google.com/rss?hl=en-IN&gl=IN&ceid=IN:en"
    response = requests.get(url)

    soup = BeautifulSoup(response.content, features="xml")
    items = soup.findAll('item')

    news_list = []

    for i, item in enumerate(items[:5]):  # Top 5 news
        title = item.title.text
        link = item.link.text

        news_list.append(f"{i+1}. {title}\n{link}\n")

    return "\n".join(news_list)

# %%
def generate_report():
    print("Fetching news...")

    news = fetch_news()
    date = datetime.now().strftime("%Y-%m-%d %H:%M")

    report = f"""
    📅 Date: {date}

    📰 Top News Updates:

    {news}

    ---
    Generated by your Web Scraping Agent 🤖
    """

    return report

# %%
def send_email(report):
    sender_email = "your_email@gmail.com"
    receiver_email = "your_email@gmail.com"
    password = "your_app_password"

    message = f"Subject: Daily News Update\n\n{report}"

    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message)
        server.quit()

        print("✅ Email sent successfully!")

    except Exception as e:
        print("❌ Error:", e)

# %%
def job():
    report = generate_report()
    print(report)
    send_email(report)

# %%
def fetch_news():
    import requests
    from bs4 import BeautifulSoup

    url = "https://news.google.com/rss?hl=en-IN&gl=IN&ceid=IN:en"
    response = requests.get(url)

    soup = BeautifulSoup(response.content, features="xml")
    items = soup.findAll('item')

    news_list = []

    for i, item in enumerate(items[:5]):
        title = item.title.text
        link = item.link.text

        news_list.append(f"{i+1}. {title}\n{link}\n")

    return "\n".join(news_list)

# %%
from datetime import datetime
job()

# %%
import smtplib

def send_email(report):
    sender_email = "pran13092003@gmail.com"
    receiver_email = "pran13092003@gmail.com"
    password = "abcdefghijklmnop"

    message = f"Subject: Daily News Update\n\n{report}"

    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.starttls()
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message)
        server.quit()

        print("✅ Email sent successfully!")

    except Exception as e:
        print("❌ Error:", e)

# %%
def job():
    report = generate_report()
    print(report)
    send_email(report)

# %%
job()
